# %%
from by_model import BY

# %%
from stability_plots import generate_plot_by

# %% [markdown]
# ## new

# %% [markdown]
# generate_plot_by('φ_d', 0.25, 1.5, 'ψ', 0.05, 2.5, G=5,
#                  coords=(-225, -30), one_step=True)

# %% [markdown]
# ## new

# %%
generate_plot_by('γ', 0.125, 1.2, 
                 'β', 0.99, 1.00125,
                 coords=(-225, -30), 
                 G=5)
# Out:
# Hit iteration upper bound when computing fixed point of T!

# %%
generate_plot_by('γ', 0.125, 1.2, 
                 'β', 0.99, 1.00125,
                 coords=(-225, -30), 
                 G=5, 
                 one_step=True)

# %% [markdown]
# ## new

# %%
generate_plot_by('β', 0.98, 1.00125, 'μ_c', -0.1, 4.0, 
                 ylabel="$\mu_c$",
                 coords=(-100, 30), 
                 G=5)
# Out:
# Hit iteration upper bound when computing fixed point of T!
# Hit iteration upper bound when computing fixed point of T!

# %%
generate_plot_by('β', 0.98, 1.00125, 'μ_c', -0.1, 4.20, 
                 ylabel="$\mu_c$",
                 coords=(-100, 30),
                 one_step=True,
                 G=5)
# Out:
# Hit iteration upper bound when computing fixed point of T!
# Hit iteration upper bound when computing fixed point of T!

# %% [markdown]
# ## new

# %%
generate_plot_by('β', 0.98, 1.00125, 'μ_d', 0.05, 5.2, 
                 ylabel="$\mu_d$",
                 coords=(-100, 30), 
                 G=5)

# %%
generate_plot_by('β', 0.98, 1.00125, 'μ_d', 0.05, 5.2, 
                 ylabel="$\mu_d$",
                 coords=(-100, 30),
                 one_step=True,
                 G=5)

# %% [markdown]
# ## new

# %% [markdown]
# generate_plot_by('β', 0.985, 1.0012,
#                  'φ_σ', 0.01, 2.0,
#                  ylabel="$\phi_d$",
#                  coords=(-50, 30), G=5)

# %% [markdown]
# generate_plot_by('β', 0.985, 1.0012,
#                  'φ_σ', 0.01, 2.0,
#                  ylabel="$\phi_d$",
#                  coords=(-50, 30),
#                  one_step=True,
#                  G=5)

# %% [markdown]
# ## new

# %% [markdown]
# generate_plot_by('β', 0.985, 1.0012,
#                  'd', 0.01, 10.0,
#                  coords=(-50, 30),
#                  G=5,
#                  one_step=True)

# %% [markdown]
# generate_plot_by('β', 0.985, 1.0012,
#                  'd', 0.01, 10.0,
#                  coords=(-50, 30),
#                  G=5)

# %% [markdown]
# ## new

# %% [markdown]
# generate_plot_by('β', 0.985, 1.0012, 'φ_z', 0.01, 4.0,
#                  coords=(-50, 30), G=2)

# %% [markdown]
# generate_plot_by('β', 0.985, 1.0012,
#                  'φ_z', 0.01, 4.0,
#                  one_step=True,
#                  coords=(-50, 30), G=2)
