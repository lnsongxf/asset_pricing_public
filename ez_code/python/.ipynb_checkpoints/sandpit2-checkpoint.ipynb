# %%
from by_model import BY

# %%
from stability_plots import generate_plot_by

# %%
generate_plot_by('φ_d', 0.25, 2.5, 'μ_d', 0.25, 2.5, G=4)
# Out:
# x_vals = [ 1.125  4.5    7.875 11.25 ]
# y_vals = [0.000375 0.0015   0.002625 0.00375 ]
# φ_d = 1.125
# μ_d = 0.000375
# r = 0.9939236548593998
# φ_d = 1.125
# μ_d = 0.0015
# r = 0.9950424481743585
# φ_d = 1.125
# μ_d = 0.0026249999999999997
# r = 0.9961625008400485
# φ_d = 1.125
# μ_d = 0.00375
# r = 0.9972838142740367
# φ_d = 4.5
# μ_d = 0.000375
# r = 0.994631477838033
# φ_d = 4.5
# μ_d = 0.0015
# r = 0.9957510679019298
# φ_d = 4.5
# μ_d = 0.0026249999999999997
# r = 0.996871918213405
# φ_d = 4.5
# μ_d = 0.00375
# r = 0.9979940301910348
# φ_d = 7.875
# μ_d = 0.000375
# r = 0.995935475693552
# φ_d = 7.875
# μ_d = 0.0015
# r = 0.9970565335805321
# φ_d = 7.875
# μ_d = 0.0026249999999999997
# r = 0.9981788533673206
# φ_d = 7.875
# μ_d = 0.00375
# r = 0.9993024364743536
# φ_d = 11.25
# μ_d = 0.000375
# r = 0.9976695002527883
# φ_d = 11.25
# μ_d = 0.0015
# r = 0.9987925100151216
# φ_d = 11.25
# μ_d = 0.0026249999999999997
# r = 0.9999167838743587
# φ_d = 11.25
# μ_d = 0.00375
# ...

# %%
generate_plot_by('φ_d', 0.25, 1.5, 'μ_d', 0.25, 1.5, G=4, one_step=True)
# Out:
# x_vals = [1.125 3.    4.875 6.75 ]
# y_vals = [0.000375 0.001    0.001625 0.00225 ]
# φ_d = 1.125
# μ_d = 0.000375
# r = 1.0236590774954764
# φ_d = 1.125
# μ_d = 0.001
# r = 1.0242990643939838
# φ_d = 1.125
# μ_d = 0.0016250000000000001
# r = 1.0249394514093286
# φ_d = 1.125
# μ_d = 0.0022500000000000003
# r = 1.0255802387916564
# φ_d = 3.0
# μ_d = 0.000375
# r = 1.0235733570941263
# φ_d = 3.0
# μ_d = 0.001
# r = 1.0242132904006376
# φ_d = 3.0
# μ_d = 0.0016250000000000001
# r = 1.0248536237904788
# φ_d = 3.0
# μ_d = 0.0022500000000000003
# r = 1.0254943575137774
# φ_d = 4.875
# μ_d = 0.000375
# r = 1.023804986535019
# φ_d = 4.875
# μ_d = 0.001
# r = 1.02444506465518
# φ_d = 4.875
# μ_d = 0.0016250000000000001
# r = 1.025085542949207
# φ_d = 4.875
# μ_d = 0.0022500000000000003
# r = 1.025726421667289
# φ_d = 6.75
# μ_d = 0.000375
# r = 1.024354153208109
# φ_d = 6.75
# μ_d = 0.001
# r = 1.0249945746647222
# φ_d = 6.75
# μ_d = 0.0016250000000000001
# r = 1.0256353965098521
# ...

# %%
generate_plot_by('φ_d', 0.25, 1.5, 'ψ', 0.05, 2.5, G=4)
# Out:
# x_vals = [1.125 3.    4.875 6.75 ]
# y_vals = [0.075 1.3   2.525 3.75 ]
# φ_d = 1.125
# ψ = 0.07500000000000001
# r = nan
# φ_d = 1.125
# ψ = 1.2999999999999998
# r = 0.9955046717401456
# φ_d = 1.125
# ψ = 2.525
# r = 0.9956345894825356
# φ_d = 1.125
# ψ = 3.75
# r = 0.9956796667094906
# φ_d = 3.0
# ψ = 0.07500000000000001
# r = nan
# φ_d = 3.0
# ψ = 1.2999999999999998
# r = 0.9958167815522175
# φ_d = 3.0
# ψ = 2.525
# r = 0.9959490422218183
# φ_d = 3.0
# ψ = 3.75
# r = 0.9959949243776929
# φ_d = 4.875
# ψ = 0.07500000000000001
# r = nan
# φ_d = 4.875
# ψ = 1.2999999999999998
# r = 0.9963307164180116
# φ_d = 4.875
# ψ = 2.525
# r = 0.9964657194690124
# φ_d = 4.875
# ψ = 3.75
# r = 0.9965125488519961
# φ_d = 6.75
# ψ = 0.07500000000000001
# r = nan
# φ_d = 6.75
# ψ = 1.2999999999999998
# r = 0.9970259539832056
# φ_d = 6.75
# ψ = 2.525
# r = 0.997163830773586
# φ_d = 6.75
# ψ = 3.75
# r = 0.9972116594776441
# ...

# %%
generate_plot_by('φ_d', 0.25, 1.5, 'ψ', 0.05, 2.5, G=4, one_step=True)
# Out:
# x_vals = [1.125 3.    4.875 6.75 ]
# y_vals = [0.075 1.3   2.525 3.75 ]
# φ_d = 1.125
# ψ = 0.07500000000000001
# r = 1.0117323314091549
# φ_d = 1.125
# ψ = 1.2999999999999998
# r = 1.018316823378319
# φ_d = 1.125
# ψ = 2.525
# r = 1.021419438313458
# φ_d = 1.125
# ψ = 3.75
# r = 1.0225144643430841
# φ_d = 3.0
# ψ = 0.07500000000000001
# r = 1.0117656322906103
# φ_d = 3.0
# ψ = 1.2999999999999998
# r = 1.018237365406509
# φ_d = 3.0
# ψ = 2.525
# r = 1.021336813361775
# φ_d = 3.0
# ψ = 3.75
# r = 1.0224307546571358
# φ_d = 4.875
# ψ = 0.07500000000000001
# r = 1.0121163759204077
# φ_d = 4.875
# ψ = 1.2999999999999998
# r = 1.0184738312950583
# φ_d = 4.875
# ψ = 2.525
# r = 1.0215709566335767
# φ_d = 4.875
# ψ = 3.75
# r = 1.0226641120038105
# φ_d = 6.75
# ψ = 0.07500000000000001
# r = 1.0127848733443718
# φ_d = 6.75
# ψ = 1.2999999999999998
# r = 1.019026413749695
# φ_d = 6.75
# ψ = 2.525
# r = 1.0221220585850999
# φ_d = 6.75
# ψ = 3.75
# r = 1.0232147260837923
# ...

# %%
generate_plot_by('μ_d', 0.5, 1.5, 'β', 0.95, 1.0, G=4, one_step=True)
# Out:
# x_vals = [0.00075 0.00125 0.00175 0.00225]
# y_vals = [0.9481     0.96473333 0.98136667 0.998     ]
# μ_d = 0.00075
# β = 0.9480999999999999
# r = 0.9567192584023172
# μ_d = 0.00075
# β = 0.9647333333333333
# r = 0.9744344000346501
# μ_d = 0.00075
# β = 0.9813666666666666
# r = 0.9938744793111133
# μ_d = 0.00075
# β = 0.998
# r = 1.020365740174463
# μ_d = 0.0012500000000000002
# β = 0.9480999999999999
# r = 0.9571977376413587
# μ_d = 0.0012500000000000002
# β = 0.9647333333333333
# r = 0.9749217390592705
# μ_d = 0.0012500000000000002
# β = 0.9813666666666666
# r = 0.9943715408057875
# μ_d = 0.0012500000000000002
# β = 0.998
# r = 1.0208760506115269
# μ_d = 0.0017500000000000003
# β = 0.9480999999999999
# r = 0.95767645617984
# μ_d = 0.0017500000000000003
# β = 0.9647333333333333
# r = 0.9754093218143305
# μ_d = 0.0017500000000000003
# β = 0.9813666666666666
# r = 0.9948688508933516
# μ_d = 0.0017500000000000003
# β = 0.998
# r = 1.0213866162676082
# μ_d = 0.0022500000000000003
# ...

# %%
generate_plot_by('μ_d', 0.5, 1.5, 'β', 0.95, 1.0, G=4)
# Out:
# x_vals = [0.00075 0.00125 0.00175 0.00225]
# y_vals = [0.9481     0.96473333 0.98136667 0.998     ]
# μ_d = 0.00075
# β = 0.9480999999999999
# r = 0.0
# μ_d = 0.00075
# β = 0.9647333333333333
# r = 0.9634547184633023
# μ_d = 0.00075
# β = 0.9813666666666666
# r = 0.9790520765092628
# μ_d = 0.00075
# β = 0.998
# r = 0.9940707498543674
# μ_d = 0.0012500000000000002
# β = 0.9480999999999999
# r = 0.0
# μ_d = 0.0012500000000000002
# β = 0.9647333333333333
# r = 0.9639365662744482
# μ_d = 0.0012500000000000002
# β = 0.9813666666666666
# r = 0.9795417249494265
# μ_d = 0.0012500000000000002
# β = 0.998
# r = 0.9945679095088507
# μ_d = 0.0017500000000000003
# β = 0.9480999999999999
# r = 0.0
# μ_d = 0.0017500000000000003
# β = 0.9647333333333333
# r = 0.9644186550697407
# μ_d = 0.0017500000000000003
# β = 0.9813666666666666
# r = 0.9800316182750264
# μ_d = 0.0017500000000000003
# β = 0.998
# r = 0.9950653178053166
# μ_d = 0.0022500000000000003
# β = 0.9480999999999999
# r = 0.0
# ...
